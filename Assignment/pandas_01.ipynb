# %% [markdown]
# # Assignment 1 — Inspecting a New Dataset
#
# **Pandas Basics · Introduction to Machine Learning · Dataset: Titanic**
#
# > Submit one notebook file named `RollNumber_Assignment1.ipynb`.
#
# ---
#
# ## Setup
#
# ```python
# import pandas as pd
# import seaborn as sns
#
# t = sns.load_dataset('titanic')
# # If the above does not work:
# # t = pd.read_csv('titanic.csv')

# %% [markdown]
# ### Q1
#
# ```markdown
# ## Q1. Load the dataset into `t`. How many rows and how many columns does it have?
#
# ```python
# # Q1
# t.shape

# %%
# Write your answer here after running the code.

# Example format:

# The dataset has _____ rows and _____ columns.

# %% [markdown]
# ### Q2
#
# ```markdown
# ## Q2. Print all the column names. Pick any three and write in a comment what you think each one holds.
#
# ```python
# # Q2
# print(t.columns)

# %%
# Pick any three columns and explain what you think they contain.
# Example:
# age    -> passenger's age
# sex    -> passenger's sex
# class  -> passenger's ticket class

# %% [markdown]
# ### Q3
#
# ```markdown
# ## Q3. Display the first 7 rows and the last 3 rows.
#
# ```python
# # Q3
# print("First 7 rows:")
# display(t.head(7))
#
# print("Last 3 rows:")
# display(t.tail(3))

# %% [markdown]
# ### Q4
#
# ```markdown
# ## Q4. Run `t.info()`. Some columns have fewer values than the total number of rows. Write down which columns those are, and how many values are missing from each.
#
# ```python
# # Q4
# t.info()

# %% [markdown]
# ### Q5
#
# ```markdown
# ## Q5. Run `t.describe()`. It shows fewer columns than `info()` listed. Write down two columns it left out, and explain why.
#
# ```python
# # Q5
# t.describe()

# %% [markdown]
# ### Q6
#
# ```markdown
# ## Q6. For the `class` column, answer all three questions below using a different function for each.
#
# ### Q6(a). How many different values are there?
#
# ```python
# # Q6(a)
# t['class'].nunique()

# %% [markdown]
# # Q6(b)
# t['class'].unique()

# %% [markdown]
# # Q6(c)
# t['class'].value_counts()

# %% [markdown]
# ### Q7
#
# ```markdown
# ## Q7. Find how many passengers were male and how many were female.
#
# ```python
# # Q7
# t['sex'].value_counts()

# %% [markdown]
# ### Q8
#
# ```markdown
# ## Q8. In `describe()`, look at the `age` column. Compare its mean with its 50% value. Which is larger, and what does that suggest about the passengers' ages?
#
# ```python
# # Q8
# t.describe()

# %% [markdown]
# ### Q9
#
# ```markdown
# ## Q9. Challenge — The `age` column has missing values. Using only `shape` and `info()`, work out what percentage of age values are missing. Write the number in a comment.
#
# ```python
# # Q9
#
# # Total number of rows
# total_rows = t.shape[0]
#
# # Run t.info() and find the number of non-null age values.
# t.info()
#
# # Replace _____ with the number of non-null age values shown by info().
# non_null_age = _____
#
# missing_age = total_rows - non_null_age
# missing_percentage = (missing_age / total_rows) * 100
#
# # Percentage of age values missing:
# print(missing_percentage)
#
# # Write the final percentage in a comment:
# # Age values missing = _____%

# %% [markdown]
# ### Submission
#
# ```markdown
# ---
#
# ## Submission
#
# Save the completed notebook as:
#
# ```text
# RollNumber_Assignment1.ipynb
